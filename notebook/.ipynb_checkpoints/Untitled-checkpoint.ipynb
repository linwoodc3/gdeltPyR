# %%
import gdelt

# %%
gd = gdelt.gdelt(version=2)

# %%
results.

# %%
test = gd.Search('2016 Oct 30',table='mentions')

# %%
test
# Out:
#       GLOBALEVENTID   EventTimeDate  MentionTimeDate  MentionType  \
# 0         594007659  20161030003000   20161030003000            1
# 1         594007660  20161030003000   20161030003000            1
# 2         594007661  20161030003000   20161030003000            1
# 3         480558166  20151031000000   20161030003000            1
# 4         594007662  20161030003000   20161030003000            1
# 5         594007663  20161030003000   20161030003000            1
# 6         594007664  20161030003000   20161030003000            1
# 7         594007665  20161030003000   20161030003000            1
# 8         594007666  20161030003000   20161030003000            1
# 9         594007667  20161030003000   20161030003000            1
# 10        480575135  20151031010000   20161030003000            1
# 11        480575135  20151031010000   20161030003000            1
# 12        480562591  20151031001500   20161030003000            1
# ...

# %%
results = gd.Search(['2016 Oct ','2016 Oct 31'],coverage=True)
# Out:
# /Users/linwood/anaconda2/envs/gdelt/lib/python3.5/site-packages/gdelt/parallel.py:39: UserWarning: GDELT did not return data for date time 20161031130000
#   warnings.warn(message)
# /Users/linwood/anaconda2/envs/gdelt/lib/python3.5/site-packages/gdelt/parallel.py:39: UserWarning: GDELT did not return data for date time 20161031131500
#   warnings.warn(message)
# /Users/linwood/anaconda2/envs/gdelt/lib/python3.5/site-packages/gdelt/parallel.py:39: UserWarning: GDELT did not return data for date time 20161031133000
#   warnings.warn(message)
# /Users/linwood/anaconda2/envs/gdelt/lib/python3.5/site-packages/gdelt/parallel.py:39: UserWarning: GDELT did not return data for date time 20161031140000
#   warnings.warn(message)
# /Users/linwood/anaconda2/envs/gdelt/lib/python3.5/site-packages/gdelt/parallel.py:39: UserWarning: GDELT did not return data for date time 20161031134500
#   warnings.warn(message)
# ...

# %%
results.EventCode.astype('str')
def badFilter(row):
    try:
        if row >=180:
            return row
    except:
        pass

# %%
results.EventCode[(results.Actor1Code.str.contains('MIL')) | (results.Actor1Code.str.contains('COP')) ]
# Out:
# 11         15
# 12         15
# 16         10
# 17         10
# 57        190
# 58        190
# 59        190
# 64         90
# 65         90
# 66         90
# 67        152
# 68         42
# 69         42
# 604       192
# 605       192
# 897        10
# 898        10
# 899        10
# 900        10
# 901        10
# 902        10
# 903        11
# 904        12
# 905        12
# 906        18
# 907        20
# 908        20
# 909        20
# 910        20
# 911        20
#          ...
# 837145     42
# 837146     42
# 837147    190
# 837148    190
# 837339     84
# 837394    173
# 837395    173
# 837396    173
# 837470     10
# 837471     13
# 837472    112
# 837528    190
# 837529    190
# 837566    190
# 837598    173
# 837599    173
# 837600    173
# 837601    173
# 837602    173
# 837603    173
# 837892    112
# 837893    193
# 837894    173
# 837895    173
# 837896    190
# 837952     26
# 837953    190
# 837954    190
# 837955    190
# 837956    190
# ...

# %%
results.

# %%
results[(results.Actor1Type2Code.notnull()) & 
        (results.Actor1Code.str.contains('MIL')) & (results.EventCode)]
# Out:
#         GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate  \
# 16          593039179  20151028     201510  2015     2015.8164
# 17          593039180  20151028     201510  2015     2015.8164
# 1690        593040853  20161027     201610  2016     2016.8137
# 1816        593040979  20161027     201610  2016     2016.8137
# 2635        593041798  20161027     201610  2016     2016.8137
# 2675        593041838  20161027     201610  2016     2016.8137
# 2676        593041839  20161027     201610  2016     2016.8137
# 2677        593041840  20161027     201610  2016     2016.8137
# 3481        593042644  20161027     201610  2016     2016.8137
# 3482        593042645  20161027     201610  2016     2016.8137
# 3655        593044303  20161020     201610  2016     2016.7945
# 5195        593045843  20161027     201610  2016     2016.8137
# 5196        593045844  20161027     201610  2016     2016.8137
# 5197        593045845  20161027     201610  2016     2016.8137
# ...

# %%
import pandas as pd
from io import BytesIO
import requests

r = requests.get('http://data.gdeltproject.org/gdeltv2/20161030121500.export.CSV.zip')
b = pd.read_csv(BytesIO(r.content),compression='zip', sep='\t',
                            header=None, warn_bad_lines=False,dtype={26:'str',27:'str',28:'str'},parse_dates=[1,2,59])

# %%
def cameos(x):
    try:
        return codes['Description'][x]
    except:
        return ("No Description returned for CAMEO code {0}".format(x))

# %%
b[26][b[26]=='0214'].apply(cameos)
# Out:
# 706    Make an appeal for, request, or suggest sharin...
# 707    Make an appeal for, request, or suggest sharin...
# Name: 26, dtype: object

# %%
results.fillna('',inplace=True)

# %%
bob = results.loc[:,'Actor1Type1Code':'Actor1Type3Code'].copy()

# %%
for index,x in enumerate(test.columns):
    print (index,x)
# Out:
# 0 GLOBALEVENTID
# 1 EventTimeDate
# 2 MentionTimeDate
# 3 MentionType
# 4 MentionSourceName
# 5 MentionIdentifier
# 6 SentenceID
# 7 Actor1CharOffset
# 8 Actor2CharOffset
# 9 ActionCharOffset
# 10 InRawText
# 11 Confidence
# 12 MentionDocLen
# 13 MentionDocTone
# 14 MentionDocTranslationInfo
# 15 Extras

# %%
codes['cameoCode']['019']= '019'

# %%
import json
codes = json.load(open('../utils/schema_csvs/cameoCodes.json'))

# %%
df=pd.DataFrame(codes)

# %%
df.to_csv('../utils/schema_csvs/cameoCodeTable.tsv',sep='\t')

# %%
pd.read_csv('../utils/schema_csvs/cameoCodeTable.tsv',sep='\t',dtype={'GoldsteinScale':str,'cameoCode':str})
# Out:
#      Unnamed: 0                                        Description  \
# 0             1                              MAKE PUBLIC STATEMENT
# 1            10                Make statement, not specified below
# 2            11                                    Decline comment
# 3            12                           Make pessimistic comment
# 4            13                            Make optimistic comment
# 5            14                             Consider policy option
# 6            15                Acknowledge or claim responsibility
# 7            16                            Make empathetic comment
# 8            17                             Engage in symbolic act
# 9            18                                     Express accord
# 10           19  Express common understanding, agreement, or ac...
# 11            2                                             APPEAL
# 12           20                        Appeal, not specified below
# ...

# %%
codes['GoldsteinScale']['019']='3.4'

# %%
json.dump(codes,open('../utils/schema_csvs/cameoCodes.json','w'))
